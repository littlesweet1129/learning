# %%
# %pwd
# Out:
# '/Users/teresazhang/github/public'

# %%
import os
os.chdir('/Users/teresazhang/github/public/learning/work_space/mlflow')

# %%
from __future__ import print_function

import numpy as np
from sklearn.datasets import load_boston
from sklearn.linear_model import LogisticRegression

import mlflow
import mlflow.sklearn

with mlflow.start_run():
    X = np.array([-2, -1, 0, 1, 2, 1]).reshape(-1, 1)
    y = np.array([0, 0, 1, 1, 1, 0])
    lr = LogisticRegression()
    lr.fit(X, y)
    score = lr.score(X, y)
    print("Score: %s" % score)
    mlflow.log_metric("score", score)
    mlflow.sklearn.log_model(lr, "model")
    print("Model saved in run %s" % mlflow.active_run().info.run_uuid)
# Out:
# Score: 0.6666666666666666
# Model saved in run 6bbf5b76e50d400f9a45a0c0b03ce64e
# /Users/teresazhang/anaconda3/envs/py35/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
